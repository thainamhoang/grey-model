# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Import data
path = '/Users/thainam/Documents/GitHub/grey-model/data/data_render/nCoV_data_render.csv'
data = pd.read_csv(path)
data["Date"] = pd.to_datetime(data["Date"])
index_data = data.set_index(["Date"], drop=True)

# Check data
index_data.head(20)
# Out:
#             Total cases
# Date
# 2020-01-28         6061
# 2020-01-29         7816
# 2020-01-30         9821
# 2020-01-31        11948
# 2020-02-01        14551
# 2020-02-02        17387
# 2020-02-03        20047
# 2020-02-04        24553
# 2020-02-05        28276
# 2020-02-06        31439
# 2020-02-07        34875
# 2020-02-08        37552

# %%
df = index_data[["Total cases"]]
df.plot()

# %%
# Split data
split_date = pd.Timestamp('2020-02-08')
split_date2 = pd.Timestamp('2020-01-28')

train = df.loc[:split_date]
test = df.loc[split_date2:]

# Plot splitted data
ax = train.plot()
test.plot(ax=ax)
plt.legend(['train', 'test'])

# %%
# Scaling
from sklearn.preprocessing import MinMaxScaler

scale = MinMaxScaler()
train_scale = scale.fit_transform(train)
test_scale = scale.transform(test)

# %%
# Split data into x and y
X_train = train_scale[:-1]
y_train = train_scale[1:]

X_test = test_scale[:-1]
y_test = test_scale[1:]

# %%
from keras.models import Sequential
from keras.layers import Dense
import keras.backend as K
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
K.clear_session()

model = Sequential()
model.add(Dense(10, input_dim=1, activation='tanh'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer ='relu')
early_stop = EarlyStopping(monitor ='loss', patience=15, verbose=1)
history = model.fit(X_train, y_train, epochs=200, batch_size=1, verbose=1, callbacks=[early_stop], shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-cee824195e20> in <module>
#       4 model.add(Dense(10, input_dim=1, activation='tanh'))
#       5 model.add(Dense(1))
# ----> 6 model.compile(loss='mean_squared_error', optimizer ='relu')
#       7 early_stop = EarlyStopping(monitor ='loss', patience=15, verbose=1)
#       8 history = model.fit(X_train, y_train, epochs=200, batch_size=1, verbose=1, callbacks=[early_stop], shuffle=False)
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in symbolic_fn_wrapper(*args, **kwargs)
#      73         if _SYMBOLIC_SCOPE.value:
#      74             with get_graph().as_default():
# ---> 75                 return func(*args, **kwargs)
#      76         else:
#      77             return func(*args, **kwargs)
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/keras/engine/training.py in compile(self, optimizer, loss, metrics, loss_weights, sample_weight_mode, weighted_metrics, target_tensors, **kwargs)
#      93                 `optimizer`, `loss`, `metrics` or `sample_weight_mode`.
#      94         """
# ---> 95         self.optimizer = optimizers.get(optimizer)
#      96         self.loss = loss or {}
#      97         self._compile_metrics = metrics or []
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/keras/optimizers.py in get(identifier)
#     866     elif isinstance(identifier, six.string_types):
#     867         config = {'class_name': str(identifier), 'config': {}}
# --> 868         return deserialize(config)
#     869     if isinstance(identifier, Optimizer):
#     870         return identifier
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/keras/optimizers.py in deserialize(config, custom_objects)
#     831                                     module_objects=all_classes,
#     832                                     custom_objects=custom_objects,
# --> 833                                     printable_module_name='optimizer')
#     834
#     835
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     138             if cls is None:
#     139                 raise ValueError('Unknown ' + printable_module_name +
# --> 140                                  ': ' + class_name)
#     141         if hasattr(cls, 'from_config'):
#     142             custom_objects = custom_objects or {}
#
# ValueError: Unknown optimizer: relu

# %%
# Prediction
y_pred_test_ann = model.predict(X_test)
y_train_pred_ann = model.predict(X_train)

# %%
# Save model
model.save('ANN_nCoV.h5')

# %%
model_ann = load_model('ANN_nCoV.h5')
y_pred_test_ANN = model_ann.predict(X_test)

# %%
# Save data
col1 = pd.DataFrame(y_test, columns=['True'])
col2 = pd.DataFrame(y_pred_test_ANN, columns=['ANN Prediction'])
col3 = pd.DataFrame(history.history['loss'], columns=['Loss_ANN'])

results = pd.concat([col1, col2, col3], axis=1)
results.to_csv('ANN_abc.csv')

# %%
# Graphing
plt.plot(y_test, label='True')
plt.plot(y_pred_test_ANN, label='ANN')
plt.title("ANN Prediction")
plt.xlabel('Observation')
plt.ylabel('Population')
plt.legend()
plt.show()

# %%
# R2 score
def adj_r2_score(r2, n, k):
    return 1-((1-r2)*((n-1)/(n-k-1)))

# MAPE
def MAPE(y, y_pred):
    y, y_pred = np.array(y), np.array(y_pred)
    return (np.mean(np.abs((y - y_pred) / y)) * 100)

# %%
from sklearn.metrics import r2_score
# Scoring
score_ann = model_ann.evaluate(X_test, y_test, batch_size=1)
print('ANN: %f'%score_ann)

# MAPE 
print("MAPE score is: " + str(MAPE(y_test, y_pred_test_ANN)))

# R2 Scores
print("The R2 score on the Train set is:\t{:0.9f}".format(r2_score(y_train, y_train_pred_ann)))
r2_train = r2_score(y_train, y_train_pred_ann)
print("The Adjusted R2 score on the Train set is:\t{:0.9f}\n".format(adj_r2_score(r2_train, X_train.shape[0], X_train.shape[1])))
print("The R2 score on the Test set is:\t{:0.9f}".format(r2_score(y_test, y_pred_test_ann)))
r2_test = r2_score(y_test, y_pred_test_ann)
print("The Adjusted R2 score on the Test set is:\t{:0.9f}".format(adj_r2_score(r2_test, X_test.shape[0], X_test.shape[1])))
# Out:
# 11/11 [==============================] - 0s 1ms/step
# ANN: 0.000164
# MAPE score is: 1.7875668053377327
# The R2 score on the Train set is:	0.998327656
# The Adjusted R2 score on the Train set is:	0.998141840
#
# The R2 score on the Test set is:	0.998327656
# The Adjusted R2 score on the Test set is:	0.998141840
