# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
gm_pred = pd.read_csv('/Users/thainam/Documents/GitHub/grey-model/prediction/Final/nCoV_GM_pred.csv')

# %%
# GM section
gm_pred["Date"] = pd.to_datetime(gm_pred["Date"])
i_gm_pred = gm_pred.set_index(["Date"], drop=True)

i_gm_pred.head(22)
# Out:
#             Actual Data  ONGBM(1, 1)  RONGBM(1, 1)
# Date
# 2020-01-28       6061.0         6061          6061
# 2020-01-29       7816.0         7130          7258
# 2020-01-30       9821.0         9824          9822
# 2020-01-31      11948.0        12378         12418
# 2020-02-01      14551.0        15056         15098
# 2020-02-02      17387.0        17860         17898
# 2020-02-03      20626.0        20793         20842
# 2020-02-04      24553.0        23862         23953
# 2020-02-05      28276.0        27068         27251
# 2020-02-06      31439.0        30417         30755
# 2020-02-07      34875.0        33915         34483
# 2020-02-08      37552.0        37564         38455
# 2020-02-09          NaN        41373         41373
# 2020-02-10          NaN        45344         45050
# 2020-02-11          NaN        49484         48461
# 2020-02-12          NaN        53799         52176
# 2020-02-13          NaN        58295         56045
# ...

# %%
df = i_gm_pred[["Actual Data", "ONGBM(1, 1)", "RONGBM(1, 1)"]]
df.plot()

# %%
split = pd.Timestamp('2020-02-08')
data = i_gm_pred.loc[:split, :1].values
# ongbm1 = i_gm_pred.iloc[:split, 1:2].values
# rongbm1 = i_gm_pred.iloc[:split, 2:3].values

# ongbm1_pred = i_gm_pred.iloc[split:, 1:2].values
# rongbm1_pred = i_gm_pred.iloc[split:, 2:3].values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-bc3fc41f72ba> in <module>
#       1 split = pd.Timestamp('2020-02-08')
# ----> 2 data = i_gm_pred.loc[:split, :1].values
#       3 # ongbm1 = i_gm_pred.iloc[:split, 1:2].values
#       4 # rongbm1 = i_gm_pred.iloc[:split, 2:3].values
#       5
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1758                 except (KeyError, IndexError, AttributeError):
#    1759                     pass
# -> 1760             return self._getitem_tuple(key)
#    1761         else:
#    1762             # we by definition only have the 0th axis
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1285                 continue
#    1286
# ...

# %%
plt.plot(data)
plt.plot(ongbm1)
plt.plot(rongbm1)
plt.plot(ongbm1_pred)
plt.plot(rongbm1_pred)
plt.xlabel("Date")
plt.ylabel("Total infected cases")
plt.legend(['Actual data', 'ONGBM(1, 1)', 'RONGBM(1, 1)', 'ONGBM(1, 1) prediction', 'RONGBM(1, 1) prediction'])
